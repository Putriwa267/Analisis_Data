# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('input/Dummy.xlsx')

# %%
columns_names = df.columns.tolist()
print("Columns name :")
print(columns_names)
# Out:
# Columns name :
# ['MQ2', 'MQ3', 'MQ4', 'MQ5', 'MQ6', 'MQ7', 'MQ8', 'MQ135', 'Label']

# %%
df.shape
# Out:
# (500, 9)

# %%
df.head()
# Out:
#    MQ2  MQ3  MQ4  MQ5  MQ6   MQ7    MQ8  MQ135  Label
# 0    6  148   72   35    0  33.6  0.627     50      3
# 1    1   85   66   29    0  26.6  0.351     31      3
# 2    8  183   64    0    0  23.3  0.672     32      3
# 3    1   89   66   23   94  28.1  0.167     21      2
# 4    0  137   40   35  168  43.1  2.288     33      1

# %%
#df_drop = df.drop(labels=['Label'], axis = 1)
#df_drop.head()

# %%
df.corr()
# Out:
#             MQ2       MQ3       MQ4       MQ5       MQ6       MQ7       MQ8
# MQ2    1.000000  0.188286  0.123546 -0.067533 -0.048876  0.042959 -0.040511  \
# MQ3    0.188286  1.000000  0.112158  0.023377  0.340892  0.236850  0.162874
# MQ4    0.123546  0.112158  1.000000  0.200149  0.086053  0.253809  0.005506
# MQ5   -0.067533  0.023377  0.200149  1.000000  0.453321  0.388162  0.165526
# MQ6   -0.048876  0.340892  0.086053  0.453321  1.000000  0.210605  0.207849
# MQ7    0.042959  0.236850  0.253809  0.388162  0.210605  1.000000  0.127520
# MQ8   -0.040511  0.162874  0.005506  0.165526  0.207849  0.127520  1.000000
# MQ135  0.528710  0.315717  0.209155 -0.135592 -0.004998  0.045232  0.042537
# Label -0.037761  0.083109  0.009552 -0.049132  0.062062  0.039548  0.036645
#
#           MQ135     Label
# MQ2    0.528710 -0.037761
# MQ3    0.315717  0.083109
# MQ4    0.209155  0.009552
# MQ5   -0.135592 -0.049132
# MQ6   -0.004998  0.062062
# MQ7    0.045232  0.039548
# MQ8    0.042537  0.036645
# MQ135  1.000000  0.060892
# Label  0.060892  1.000000

# %%
correlation = df.groupby('Label').corr()
plt.figure(figsize = (10, 10))
sns.heatmap(correlation, vmax = 1.0, square = True, annot = True, cmap = 'cubehelix')

plt.title('Correlation between different fearures')
# Out:
# Text(0.5, 1.0, 'Correlation between different fearures')
