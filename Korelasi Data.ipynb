# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <h1>PREPARING DATA</h1>

# %% [markdown]
# <h4>0. Input Data</h4>

# %%
df = pd.read_excel('input\Korelasi.xlsx')

# %%
# df.drop(['Treatmen'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     MQ2   MQ3   MQ4   MQ5   MQ6   MQ7   MQ8   MQ9  MQ135    SPAD  Nitrogen
# 0  0.28  0.37  0.81  0.35  0.17  0.10  0.35  0.40    0.1  39.055    1.7084  \
# 1  0.26  0.37  0.82  0.35  0.14  0.14  0.35  0.39    0.1  39.055    1.7084
# 2  0.26  0.37  0.82  0.35  0.14  0.10  0.35  0.40    0.1  39.055    1.7084
# 3  0.26  0.37  0.83  0.35  0.17  0.10  0.35  0.40    0.1  39.055    1.7084
# 4  0.28  0.37  0.84  0.35  0.17  0.10  0.35  0.40    0.1  39.055    1.7084
#
#    Flavonoid
# 0       1.48
# 1       1.48
# 2       1.48
# 3       1.48
# 4       1.48

# %%
df.hist(figsize=(7,9), bins=15)
plt.show()

# %%
plt.figure(figsize=(9,8))
p=sns.heatmap(df.corr(), annot=True, cmap='RdYlGn', center=0)
plt.xticks(rotation = 45, fontsize=8)
plt.yticks(rotation = 45, fontsize=8)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5]),
#  [Text(0, 0.5, 'MQ2'),
#   Text(0, 1.5, 'MQ3'),
#   Text(0, 2.5, 'MQ4'),
#   Text(0, 3.5, 'MQ5'),
#   Text(0, 4.5, 'MQ6'),
#   Text(0, 5.5, 'MQ7'),
#   Text(0, 6.5, 'MQ8'),
#   Text(0, 7.5, 'MQ9'),
#   Text(0, 8.5, 'MQ135'),
#   Text(0, 9.5, 'SPAD'),
#   Text(0, 10.5, 'Nitrogen'),
#   Text(0, 11.5, 'Flavonoid')])
