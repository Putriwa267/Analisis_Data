# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <h1>PREPARING DATA</h1>

# %% [markdown]
# <h4>0. Input Data</h4>

# %%
df = pd.read_excel('input\Korelasi.xlsx')

# %%
# df.drop(['Treatmen'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     MQ2   MQ3   MQ4   MQ5   MQ6   MQ7   MQ8   MQ9  MQ135    SPAD  Nitrogen
# 0  0.32  0.17  0.49  0.20  0.17  0.14  0.14  0.22   0.17  39.055    1.7084  \
# 1  0.30  0.20  0.51  0.17  0.17  0.14  0.10  0.22   0.17  39.055    1.7084
# 2  0.28  0.20  0.45  0.20  0.17  0.14  0.10  0.22   0.14  39.055    1.7084
# 3  0.30  0.20  0.48  0.20  0.17  0.14  0.10  0.22   0.17  39.055    1.7084
# 4  0.32  0.20  0.48  0.20  0.17  0.14  0.10  0.22   0.17  39.055    1.7084
#
#    Flavonoid
# 0       1.48
# 1       1.48
# 2       1.48
# 3       1.48
# 4       1.48

# %%
df.hist(figsize=(15,20), bins=15)
plt.show()

# %%
plt.figure(figsize=(9,8))
p=sns.heatmap(df.corr(), annot=True, cmap='RdYlGn', center=0)
