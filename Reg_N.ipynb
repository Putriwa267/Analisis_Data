# %%
from numpy import *
from scipy.interpolate import *
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.pyplot import *
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from scipy.stats import *

df = pd.read_excel('input\Korelasi.xlsx')
df.tail()
# Out:
#       MQ2   MQ3   MQ4   MQ5   MQ6   MQ7  MQ8   MQ9  MQ135  SPAD  Nitrogen
# 807  0.22  0.20  0.40  0.14  0.17  0.14  0.1  0.14   0.14  55.4    2.1858  \
# 808  0.22  0.22  0.40  0.14  0.17  0.10  0.1  0.14   0.10  55.4    2.1858
# 809  0.22  0.22  0.40  0.14  0.17  0.14  0.1  0.14   0.14  55.4    2.1858
# 810  0.22  0.22  0.41  0.17  0.17  0.14  0.1  0.14   0.14  55.4    2.1858
# 811  0.22  0.22  0.40  0.14  0.17  0.10  0.1  0.14   0.10  55.4    2.1858
#
#      Flavonoid
# 807       1.47
# 808       1.47
# 809       1.47
# 810       1.47
# 811       1.47

# %%
yfit_2 = polyfit(df['MQ2'], df['Nitrogen'], 1)[0] * df['MQ2'] + polyfit(df['MQ2'], df['Nitrogen'], 1)[1]
yres_2 = df['Nitrogen'] - yfit_2
SSresid_2 = sum(pow(yres_2,2))
SStotal_2 = len(df['Nitrogen']) * var(df['Nitrogen'])
rsq_2 = 1 - SSresid_2/SStotal_2


plot(df['MQ2'], df['Nitrogen'],'o')
ylabel('Uji Nitrogen')
xlabel('MQ2')
title("RSquare: {:.5f}".format(rsq_2), loc = 'left', fontsize=9, color='r')

xp = linspace(0.14, 0.45, 50)
plot(xp, polyval(polyfit(df['MQ2'], df['Nitrogen'], 1), xp),'r-')
plot(xp, polyval(polyfit(df['MQ2'], df['Nitrogen'], 2), xp),'b--')
plot(xp, polyval(polyfit(df['MQ2'], df['Nitrogen'], 3), xp),'m:')

# %%
fig, axs = plt.subplots(3, 3, figsize=(8,8), layout="constrained")

#----------------------------MQ2
yfit_2 = polyfit(df['MQ2'], df['Nitrogen'], 1)[0] * df['MQ2'] + polyfit(df['MQ2'], df['Nitrogen'], 1)[1]
yres_2 = df['Nitrogen'] - yfit_2
SSresid_2 = sum(pow(yres_2,2))
SStotal_2 = len(df['Nitrogen']) * var(df['Nitrogen'])
rsq_2 = 1 - SSresid_2/SStotal_2

axs[0, 0].plot(df['MQ2'], df['Nitrogen'],'o')
axs[0, 0].set_ylabel('Uji Nitrogen')
axs[0, 0].set_xlabel('MQ2')
axs[0, 0].set_title("RSquare: {:.5f}".format(rsq_2), loc = 'left', fontsize=9, color='r')


xp = linspace(0.14, 0.45, 50)
axs[0, 0].plot(xp, polyval(polyfit(df['MQ2'], df['Nitrogen'], 1), xp),'r-')
axs[0, 0].plot(xp, polyval(polyfit(df['MQ2'], df['Nitrogen'], 2), xp),'b--')
axs[0, 0].plot(xp, polyval(polyfit(df['MQ2'], df['Nitrogen'], 3), xp),'m:')


#----------------------------MQ3
yfit_3 = polyfit(df['MQ3'], df['Nitrogen'], 1)[0] * df['MQ3'] + polyfit(df['MQ3'], df['Nitrogen'], 1)[1]
yres_3 = df['Nitrogen'] - yfit_3
SSresid_3 = sum(pow(yres_2,2))
SStotal_3 = len(df['Nitrogen']) * var(df['Nitrogen'])
rsq_3 = 1 - SSresid_3/SStotal_3

axs[0, 1].plot(df['MQ3'], df['Nitrogen'],'o')
axs[0, 1].set_ylabel('Uji Nitrogen')
axs[0, 1].set_xlabel('MQ3')
axs[0, 1].set_title("RSquare: {:.5f}".format(rsq_3), loc = 'left', fontsize=9, color='r')


xp = linspace(0, 0.3, 50)
axs[0, 1].plot(xp, polyval(polyfit(df['MQ3'], df['Nitrogen'], 1), xp),'r-')
axs[0, 1].plot(xp, polyval(polyfit(df['MQ3'], df['Nitrogen'], 2), xp),'b--')
axs[0, 1].plot(xp, polyval(polyfit(df['MQ3'], df['Nitrogen'], 3), xp),'m:')



#----------------------------MQ4
yfit_4 = polyfit(df['MQ4'], df['Nitrogen'], 1)[0] * df['MQ4'] + polyfit(df['MQ4'], df['Nitrogen'], 1)[1]
yres_4 = df['Nitrogen'] - yfit_4
SSresid_4 = sum(pow(yres_4,2))
SStotal_4 = len(df['Nitrogen']) * var(df['Nitrogen'])
rsq_4 = 1 - SSresid_4/SStotal_4

axs[0, 2].plot(df['MQ4'], df['Nitrogen'],'o')
axs[0, 2].set_ylabel('Uji Nitrogen')
axs[0, 2].set_xlabel('MQ4')
axs[0, 2].set_title("RSquare: {:.5f}".format(rsq_4), loc = 'left', fontsize=9, color='r')

xp = linspace(0.1, 0.6, 50)
axs[0, 2].plot(xp, polyval(polyfit(df['MQ4'], df['Nitrogen'], 1), xp),'r-')
axs[0, 2].plot(xp, polyval(polyfit(df['MQ4'], df['Nitrogen'], 2), xp),'b--')
axs[0, 2].plot(xp, polyval(polyfit(df['MQ4'], df['Nitrogen'], 3), xp),'m:')




#----------------------------MQ5
yfit_5 = polyfit(df['MQ5'], df['Nitrogen'], 1)[0] * df['MQ5'] + polyfit(df['MQ5'], df['Nitrogen'], 1)[1]
yres_5 = df['Nitrogen'] - yfit_5
SSresid_5 = sum(pow(yres_5,2))
SStotal_5 = len(df['Nitrogen']) * var(df['Nitrogen'])
rsq_5 = 1 - SSresid_5/SStotal_5

axs[1, 0].plot(df['MQ5'], df['Nitrogen'],'o')
axs[1, 0].set_ylabel('Uji Nitrogen')
axs[1, 0].set_xlabel('MQ5')
axs[1, 0].set_title("RSquare: {:.5f}".format(rsq_5), loc = 'left', fontsize=9, color='r')

xp = linspace(0.1, 0.25, 50)
axs[1, 0].plot(xp, polyval(polyfit(df['MQ5'], df['Nitrogen'], 1), xp),'r-')
axs[1, 0].plot(xp, polyval(polyfit(df['MQ5'], df['Nitrogen'], 2), xp),'b--')
axs[1, 0].plot(xp, polyval(polyfit(df['MQ5'], df['Nitrogen'], 3), xp),'m:')


#----------------------------MQ6
yfit_6 = polyfit(df['MQ6'], df['Nitrogen'], 1)[0] * df['MQ6'] + polyfit(df['MQ6'], df['Nitrogen'], 1)[1]
yres_6 = df['Nitrogen'] - yfit_6
SSresid_6 = sum(pow(yres_6,2))
SStotal_6 = len(df['Nitrogen']) * var(df['Nitrogen'])
rsq_6 = 1 - SSresid_6/SStotal_6

axs[1, 1].plot(df['MQ6'], df['Nitrogen'],'o')
axs[1, 1].set_ylabel('Uji Nitrogen')
axs[1, 1].set_xlabel('MQ6')
axs[1, 1].set_title("RSquare: {:.5f}".format(rsq_6), loc = 'left', fontsize=9, color='r')

xp = linspace(0.0, 0.25, 50)
axs[1, 1].plot(xp, polyval(polyfit(df['MQ6'], df['Nitrogen'], 1), xp),'r-')
axs[1, 1].plot(xp, polyval(polyfit(df['MQ6'], df['Nitrogen'], 2), xp),'b--')
axs[1, 1].plot(xp, polyval(polyfit(df['MQ6'], df['Nitrogen'], 3), xp),'m:')



#----------------------------MQ7
yfit_7 = polyfit(df['MQ7'], df['Nitrogen'], 1)[0] * df['MQ7'] + polyfit(df['MQ7'], df['Nitrogen'], 1)[1]
yres_7 = df['Nitrogen'] - yfit_7
SSresid_7 = sum(pow(yres_7,2))
SStotal_7 = len(df['Nitrogen']) * var(df['Nitrogen'])
rsq_7 = 1 - SSresid_7/SStotal_7

axs[1, 2].plot(df['MQ7'], df['Nitrogen'],'o')
axs[1, 2].set_ylabel('Uji Nitrogen')
axs[1, 2].set_xlabel('MQ7')
axs[1, 2].set_title("RSquare: {:.5f}".format(rsq_7), loc = 'left', fontsize=9, color='r')

xp = linspace(0.0, 0.2, 50)
axs[1, 2].plot(xp, polyval(polyfit(df['MQ7'], df['Nitrogen'], 1), xp),'r-')
axs[1, 2].plot(xp, polyval(polyfit(df['MQ7'], df['Nitrogen'], 2), xp),'b--')
axs[1, 2].plot(xp, polyval(polyfit(df['MQ7'], df['Nitrogen'], 3), xp),'m:')


#----------------------------MQ8
yfit_8 = polyfit(df['MQ8'], df['Nitrogen'], 1)[0] * df['MQ8'] + polyfit(df['MQ8'], df['Nitrogen'], 1)[1]
yres_8 = df['Nitrogen'] - yfit_8
SSresid_8 = sum(pow(yres_8,2))
SStotal_8 = len(df['Nitrogen']) * var(df['Nitrogen'])
rsq_8 = 1 - SSresid_8/SStotal_8

axs[2, 0].plot(df['MQ8'], df['Nitrogen'],'o')
axs[2, 0].set_ylabel('Uji Nitrogen')
axs[2, 0].set_xlabel('MQ8')
axs[2, 0].set_title("RSquare: {:.5f}".format(rsq_8), loc = 'left', fontsize=9, color='r')

xp = linspace(0.1, 0.2, 50)
axs[2, 0].plot(xp, polyval(polyfit(df['MQ8'], df['Nitrogen'], 1), xp),'r-')
axs[2, 0].plot(xp, polyval(polyfit(df['MQ8'], df['Nitrogen'], 2), xp),'b--')
axs[2, 0].plot(xp, polyval(polyfit(df['MQ8'], df['Nitrogen'], 3), xp),'m:')


#----------------------------MQ9
yfit_9 = polyfit(df['MQ9'], df['Nitrogen'], 1)[0] * df['MQ9'] + polyfit(df['MQ9'], df['Nitrogen'], 1)[1]
yres_9 = df['Nitrogen'] - yfit_9
SSresid_9 = sum(pow(yres_9,2))
SStotal_9 = len(df['Nitrogen']) * var(df['Nitrogen'])
rsq_9 = 1 - SSresid_9/SStotal_9

axs[2, 1].plot(df['MQ9'], df['Nitrogen'],'o')
axs[2, 1].set_ylabel('Uji Nitrogen')
axs[2, 1].set_xlabel('MQ9')
axs[2, 1].set_title("RSquare: {:.5f}".format(rsq_9), loc = 'left', fontsize=9, color='r')

xp = linspace(0, 0.25, 50)
axs[2, 1].plot(xp, polyval(polyfit(df['MQ9'], df['Nitrogen'], 1), xp),'r-')
axs[2, 1].plot(xp, polyval(polyfit(df['MQ9'], df['Nitrogen'], 2), xp),'b--')
axs[2, 1].plot(xp, polyval(polyfit(df['MQ9'], df['Nitrogen'], 3), xp),'m:')


#----------------------------MQ135
yfit_135 = polyfit(df['MQ135'], df['Nitrogen'], 1)[0] * df['MQ135'] + polyfit(df['MQ135'], df['Nitrogen'], 1)[1]
yres_135 = df['Nitrogen'] - yfit_135
SSresid_135 = sum(pow(yres_135,2))
SStotal_135 = len(df['Nitrogen']) * var(df['Nitrogen'])
rsq_135 = 1 - SSresid_135/SStotal_135

axs[2, 2].plot(df['MQ135'], df['Nitrogen'],'o')
axs[2, 2].set_ylabel('Uji Nitrogen')
axs[2, 2].set_xlabel('MQ135')
axs[2, 2].set_title("RSquare: {:.5f}".format(rsq_135), loc = 'left', fontsize=9, color='r')

xp = linspace(0.1, 0.2, 50)
axs[2, 2].plot(xp, polyval(polyfit(df['MQ135'], df['Nitrogen'], 1), xp),'r-')
axs[2, 2].plot(xp, polyval(polyfit(df['MQ135'], df['Nitrogen'], 2), xp),'b--')
axs[2, 2].plot(xp, polyval(polyfit(df['MQ135'], df['Nitrogen'], 3), xp),'m:')
